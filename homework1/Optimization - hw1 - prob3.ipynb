# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1 = np.linspace(-1, 10, 100, endpoint=False)

# %%
# 3x1 + x2 <= 12
line1 = 12 - 3*x1

# x1 = 2

# 3*x1 - 2*x2 - x3 == 12
x3 = 0
line3 = 1.5*x1 - 6 - 0.5*x3

x3 = 1
line4 = 1.5*x1 - 6 - 0.5*x3

# obj: 3*x1 + 2*x2
obj = 1.5*x1

# %%
plt.figure(figsize=(10, 8))
plt.grid()
plt.ylim(-1, 8)
plt.xlim(1, 5)
plt.plot(x1, line1, label="line1")
plt.vlines(2, -5, 10, colors="purple", label="line2")
plt.plot(x1, line3, label="line3")
plt.plot(x1, line4, label="line4")
plt.hlines(0, 1, 5, linestyles="dashed")
plt.legend()
